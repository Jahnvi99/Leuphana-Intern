# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahnvi99/Leuphana-Intern/blob/master/2dGP_PI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gpytorch
# Out:
# Collecting gpytorch
#   Downloading https://files.pythonhosted.org/packages/4a/fa/b6db02ee0e98e89752bdae11534034251bc08317cdc325dd1878732b152d/gpytorch-1.5.0-py2.py3-none-any.whl (498kB)
#      |████████████████████████████████| 501kB 6.6MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gpytorch) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from gpytorch) (0.22.2.post1)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gpytorch) (1.9.0+cu102)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy->gpytorch) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->gpytorch) (1.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.8.1->gpytorch) (3.7.4.3)
# Installing collected packages: gpytorch
# Successfully installed gpytorch-1.5.0

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
from scipy.stats import multivariate_normal
from scipy.integrate import quad
import numpy as np
from scipy.integrate import simps
from numpy import trapz
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from scipy.stats import norm

# %%
x_0 = torch.linspace(-3, 3, 25).float()
x_1 = torch.linspace(-3, 3, 25).float()
xx, yy = torch.meshgrid(x_0, x_1)

# %%
xx.shape
# Out:
# torch.Size([25, 25])

# %%
def gaussian_2d(X):
  return torch.tensor(multivariate_normal.pdf(X, mean = [0,0])).float()
X = torch.stack((xx.ravel(), yy.ravel())).T
X.shape
# Out:
# torch.Size([625, 2])

# %%
Y = gaussian_2d(X)
Y.shape
# Out:
# torch.Size([625])

# %%
class ExactGPModel(gpytorch.models.ExactGP):
    
    def __init__(self, train_x, train_y, likelihood, use_ard = True):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        ard_num_dims = None
        if use_ard:
            ard_num_dims = train_x.shape[-1]
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(ard_num_dims = train_x.shape[-1]))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
likelihood = gpytorch.likelihoods.GaussianLikelihood()

# %%
x_sample_0 = torch.tensor([ 2.3486, -1.6099])
x_sample_1 = torch.tensor([ 0.4825, -2.9736])
sample_xx, sample_yy = torch.meshgrid(x_sample_0, x_sample_1) 
X_sample = torch.stack((sample_xx.ravel(), sample_yy.ravel())).T

# %%
X_sample.shape
# Out:
# torch.Size([4, 2])

# %%
Y_sample = gaussian_2d(X_sample)

# %%
Y_sample.dtype
# Out:
# torch.float32

# %%
for i in range(50):
  model = ExactGPModel(X_sample, Y_sample, likelihood)
  model.train()
  likelihood.train()
  optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters
  mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
  for i in range(10):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(X_sample)
    # Calc loss and backprop gradients
    loss = -mll(output, Y_sample)
    loss.backward()
    optimizer.step()

  model.eval()
  with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = X
    observed_pred = likelihood(model(test_x))
    pred_y = observed_pred.mean.reshape(xx.shape)
    fig, ax = plt.subplots(1, 1)
    # plots contour lines
    CS = ax.contour(xx, yy, pred_y)
    ax.set_title('Contour Plot')
    ax.set_xlabel('feature_x')
    ax.set_ylabel('feature_y')
    plt.clabel(CS, inline=1, fontsize=10)  
    plt.show()
  mu = observed_pred.mean
  sigma = torch.sqrt(observed_pred.variance)
  best_mu = torch.max(mu)
  tmp = (mu - best_mu - 1E-15) / sigma
  tmp = tmp.detach().numpy()
  idx = torch.argmax(torch.from_numpy(norm.cdf(tmp)))
  p = torch.unsqueeze(X[idx], 0)
  y_int = observed_pred.mean.numpy()   
  X_sample = torch.cat((X_sample, p))
  Y_sample = gaussian_2d(X_sample)

# %%
Y = Y.reshape(xx.shape)
fig, ax = plt.subplots(1, 1)
  
# plots contour lines
CS = ax.contour(xx, yy, Y)
  
ax.set_title('Contour Plot')
ax.set_xlabel('feature_x')
ax.set_ylabel('feature_y')
plt.clabel(CS, inline=1, fontsize=10)  
plt.show()
